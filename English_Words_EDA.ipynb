# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhav2702/AI_ML_AVANTHI_MADHAV/blob/main/English_Words_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
df = pd.read_csv('/content/unix-words.txt')
df
# Out:
#                  A
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df = df.rename(columns = {'A':'Words'})
df
# Out:
#              Words
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['Words'] = df['Words'].fillna('')
df['CharCount'] = df['Words'].apply(len)
df
# Out:
#              Words  CharCount
# 0                a          1
# 1               aa          2
# 2              aal          3
# 3            aalii          5
# 4              aam          3
# ...            ...        ...
# 235880      zythem          6
# 235881      Zythia          6
# 235882      zythum          6
# 235883     Zyzomys          7
# 235884  Zyzzogeton         10
#
# [235885 rows x 2 columns]

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def summing(word):
  sum = 0
  word.lower()
  for char in word:
    position = ord(char) - 96
    sum += position
  return sum
df['Values'] = df['Words'].apply(summing)

# %%
df.head()
# Out:
#    Words  CharCount  Values
# 0      a          1       1
# 1     aa          2       2
# 2    aal          3      14
# 3  aalii          5      32
# 4    aam          3      15

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235885 entries, 0 to 235884
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Words      235885 non-null  object
#  1   CharCount  235885 non-null  int64
#  2   Values     235885 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 5.4+ MB

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df.set_index('Words')
# Out:
#             CharCount  Values
# Words
# a                   1       1
# aa                  2       2
# aal                 3      14
# aalii               5      32
# aam                 3      15
# ...               ...     ...
# zythem              6      97
# Zythia              6      57
# zythum              6     113
# Zyzomys             7     117
# Zyzzogeton         10     147
#
# [235885 rows x 2 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df['Words']== 'Acanthomeridae','Values']
# Out:
# 762    85
# Name: Values, dtype: int64

# %% [markdown]
# What is the highest possible value for a word?

# %%
df.max()
# Out:
# Words        zythum
# CharCount        24
# Values          328
# dtype: object

# %%
df['Values'].max()
# Out:
# 328

# %% [markdown]
# What is the highest possible length of a word

# %%
df['CharCount'].max()
# Out:
# 24

# %% [markdown]
# What is the value of the word with Value '317'

# %%
df.loc[df['Values']==317]
# Out:
#                            Words  CharCount  Values
# 203040  thyroparathyroidectomize         24     317

# %% [markdown]
# What is the most common value?

# %%
df['Values'].mode()
# Out:
# 0    102
# Name: Values, dtype: int64

# %%
df['Values'].value_counts().head().to_frame()
# Out:
#      Values
# 102    2218
# 107    2194
# 100    2185
# 108    2184
# 115    2171

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df['Values']==107].min()
# Out:
# Words        Agriochoerus
# CharCount               5
# Values                107
# dtype: object

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df['Ratio']=df['Values']/df['CharCount']
df
# Out:
#              Words  CharCount  Values      Ratio
# 0                a          1       1   1.000000
# 1               aa          2       2   1.000000
# 2              aal          3      14   4.666667
# 3            aalii          5      32   6.400000
# 4              aam          3      15   5.000000
# ...            ...        ...     ...        ...
# 235880      zythem          6      97  16.166667
# 235881      Zythia          6      57   9.500000
# 235882      zythum          6     113  18.833333
# 235883     Zyzomys          7     117  16.714286
# 235884  Zyzzogeton         10     147  14.700000
#
# [235885 rows x 4 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
df['Ratio'].max()
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df.loc[df['Ratio']==df['Ratio'].max()]
# Out:
#        Words  CharCount  Values  Ratio
# 234937     z          1      26   26.0

# %%
df.sort_values('Values',ascending=False)
# Out:
#                            Words  CharCount  Values      Ratio
# 48117     dacryocystosyringotomy         22     328  14.909091
# 203040  thyroparathyroidectomize         24     317  13.208333
# 225854    ureterocystanastomosis         22     314  14.272727
# 104217    laparocolpohysterotomy         22     307  13.954545
# 160718    pyopneumocholecystitis         22     307  13.954545
# ...                          ...        ...     ...        ...
# 58962                          E          1     -27 -27.000000
# 48066                          D          1     -28 -28.000000
# 14                            Ab          2     -29 -14.500000
# 28165                          C          1     -29 -29.000000
# 17095                          B          1     -30 -30.000000
#
# [235885 rows x 4 columns]

# %% [markdown]
# How many words have the ratio of 10

# %%
df.loc[df['Ratio']==10].count()
# Out:
# Words        3159
# CharCount    3159
# Values       3159
# Ratio        3159
# dtype: int64

# %%
df.loc[df['Ratio']==10].value_counts()
# Out:
# Words          CharCount  Values  Ratio
# Aepyornis      9          90      10.0     1
# nakhlite       8          80      10.0     1
# naval          5          50      10.0     1
# navigableness  13         130     10.0     1
# nearsighted    11         110     10.0     1
#                                           ..
# czaric         6          60      10.0     1
# dacryoma       8          80      10.0     1
# daitya         6          60      10.0     1
# dalespeople    11         110     10.0     1
# zwieback       8          80      10.0     1
# Length: 3159, dtype: int64

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
df.loc[df['Ratio']==10].max()
# Out:
# Words        zwieback
# CharCount          21
# Values            210
# Ratio            10.0
# dtype: object

# %%
df.query('Ratio==10').max()
# Out:
# Words        zwieback
# CharCount          21
# Values            210
# Ratio            10.0
# dtype: object

# %% [markdown]
# Of all the words with the value of 260, what has the loswest character count?

# %%
df.loc[df['Values']==260].CharCount.min()
# Out:
# 17

# %%
df.query('Values==260').min()
# Out:
# Words        chromophotolithograph
# CharCount                       17
# Values                         260
# Ratio                    11.818182
# dtype: object

# %%
df.describe()
# Out:
#            CharCount         Values          Ratio
# count  235885.000000  235885.000000  235883.000000
# mean        9.569133     108.969218      11.256517
# std         2.927375      43.525601       2.766208
# min         0.000000     -30.000000     -30.000000
# 25%         8.000000      78.000000       9.846154
# 50%         9.000000     107.000000      11.545455
# 75%        11.000000     137.000000      13.000000
# max        24.000000     328.000000      26.000000
