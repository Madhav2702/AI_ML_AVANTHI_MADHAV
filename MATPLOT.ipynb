# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhav2702/AI_ML_AVANTHI_MADHAV/blob/main/MATPLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]
plt.plot(x,y)
plt.figure(figsize=(5,3),dpi=100)
plt.title('Our first sine Graph',fontdict={'fontsize':10})
plt.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
X=[2,4,6,8,10,12]
Y=[3,6,9,12,15,18]
plt.plot(X,Y)
plt.title('My first Graph',fontdict={'fontsize':10})
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')

plt.xticks([2,4,6,8,10,12])
plt.yticks([3,6,9,12,15,18])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
